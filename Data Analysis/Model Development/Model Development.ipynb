# %% [markdown]
# <h1 align=center><font size = 6, color = blue>Model Development</font></h1>

# %%
import pandas as pd

from sklearn.cluster import KMeans

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("../Data Wrangling/klinik_bewertungen_afterWrangling.csv")
df.head(2)
# Out:
#                Name der Klinik                       Titel       Datum  \
# 0  Herzogin Elisabeth Hospital                 Superklinik  2021-06-07
# 1  Herzogin Elisabeth Hospital  Kranken- oder Hotelzimmer?  2021-05-25
#
#        Fachbereich                                  Erfahrungsbericht  \
# 0       Orthopädie  Bestens durchorganisiert.gutes Personal geht i...
# 1  Unfallchirurgie  Bin nach einem Autounfall im HEH gewesen und h...
#
#   Gesamtzufriedenheit Qualität der Beratung Mediz. Behandlung  \
# 0      sehr zufrieden        sehr zufrieden    sehr zufrieden
# 1      sehr zufrieden        sehr zufrieden    sehr zufrieden
#
#   Verwaltung und Abläufe Ausstattung und Gestaltung  Polaritiy  Subjectivity  \
# 0         sehr zufrieden             sehr zufrieden       0.00           0.0
# 1         sehr zufrieden                  zufrieden       0.34           0.0
#
#    year  month  day  Gesamt  Qualität  Behandlung  Verwaltung  Ausstattung
# 0  2021      6    7   100.0     100.0       100.0       100.0        100.0
# 1  2021      5   25   100.0     100.0       100.0       100.0         67.0

# %%
df_kliniks=df[['Name der Klinik','Polaritiy','Gesamt','Qualität', 'Behandlung', 'Verwaltung', 'Ausstattung']].groupby(['Name der Klinik'],as_index=False).mean()
df_kliniks.head(2)
# Out:
#                     Name der Klinik  Polaritiy     Gesamt   Qualität  \
# 0         AMEOS Klinikum Hildesheim    0.07040  34.319767  37.581395
# 1  AMEOS Klinikum Seepark Geestland    0.27478  70.861111  74.555556
#
#    Behandlung  Verwaltung  Ausstattung
# 0   33.337209   34.116279    32.610465
# 1   76.173611   69.034722    66.701389

# %%
Rezension_zahl=df.groupby(['Name der Klinik'],as_index=False).count()["Erfahrungsbericht"].to_list()
Rezension_zahl
# Out:
# [172, 144, 241, 49, 123, 124, 128, 118, 77, 145, 105, 232, 122, 86, 52, 77, 63]

# %%
df_fach=df.groupby(['Name der Klinik','Fachbereich'],as_index=False).count()[['Name der Klinik',"Fachbereich"]]
df_fach_arten=df_fach.groupby(['Name der Klinik'],as_index=False).count()
Fach_arten=df_fach_arten["Fachbereich"].to_list()
Fach_arten
# Out:
# [6, 7, 25, 8, 14, 18, 12, 16, 11, 18, 4, 19, 17, 14, 4, 10, 14]

# %%
df_kliniks["Fach_arten"]=Fach_arten
df_kliniks
# Out:
#                       Name der Klinik  Polaritiy     Gesamt   Qualität  \
# 0           AMEOS Klinikum Hildesheim   0.070400  34.319767  37.581395
# 1    AMEOS Klinikum Seepark Geestland   0.274780  70.861111  74.555556
# 2           DIAKOVERE Henriettenstift   0.235991  60.165975  65.157676
# 3          Eilenriede Klinik Hannover   0.449850  84.367347  85.040816
# 4              HELIOS Klinik Cuxhaven   0.261306  56.910569  59.349593
# 5         Helios Kliniken Mittelweser   0.256709  54.572581  56.185484
# 6         Herzogin Elisabeth Hospital   0.371762  79.179688  78.414062
# 7   KRH Klinikum Agness Karll Laatzen   0.184622  48.610169  57.076271
# 8                Klinik am Zuckerberg   0.472796  91.350649  90.922078
# 9                      Klinikum Peine   0.275747  62.317241  67.379310
# 10               Klinikum Wahrendorff   0.165236  45.723810  47.295238
# 11                 Klinikum Wolfsburg   0.215484  58.064655  62.245690
# 12               Krankenhaus Buchholz   0.218212  45.631148  51.368852
# 13                 Krankenhaus Winsen   0.211417  59.674419  61.627907
# 14     Psychiatrische Klinik Lüneburg   0.079971  30.153846  30.769231
# 15                      Sophienklinik   0.287036  61.922078  64.961039
# 16            St. Martini Krankenhaus   0.395636  74.111111  76.761905
#
#     Behandlung  Verwaltung  Ausstattung  Fach_arten
# 0    33.337209   34.116279    32.610465           6
# 1    76.173611   69.034722    66.701389           7
# 2    69.854772   55.095436    62.414938          25
# 3    86.408163   87.816327    81.000000           8
# 4    63.959350   56.130081    57.219512          14
# 5    59.403226   55.693548    57.580645          18
# 6    81.773438   75.835938    75.335938          12
# 7    64.135593   50.635593    41.855932          16
# 8    92.649351   89.649351    90.090909          11
# 9    71.282759   64.634483    55.924138          18
# 10   43.847619   46.990476    51.438095           4
# 11   67.241379   51.336207    58.961207          19
# 12   55.204918   49.754098    46.500000          17
# 13   69.383721   60.127907    58.953488          14
# 14   35.250000   30.788462    33.365385           4
# 15   74.506494   62.831169    56.311688          10
# 16   80.460317   73.650794    68.365079          14

# %%
df_kliniks["Rezension_zahl"]=Rezension_zahl
df_kliniks
# Out:
#                       Name der Klinik  Polaritiy     Gesamt   Qualität  \
# 0           AMEOS Klinikum Hildesheim   0.070400  34.319767  37.581395
# 1    AMEOS Klinikum Seepark Geestland   0.274780  70.861111  74.555556
# 2           DIAKOVERE Henriettenstift   0.235991  60.165975  65.157676
# 3          Eilenriede Klinik Hannover   0.449850  84.367347  85.040816
# 4              HELIOS Klinik Cuxhaven   0.261306  56.910569  59.349593
# 5         Helios Kliniken Mittelweser   0.256709  54.572581  56.185484
# 6         Herzogin Elisabeth Hospital   0.371762  79.179688  78.414062
# 7   KRH Klinikum Agness Karll Laatzen   0.184622  48.610169  57.076271
# 8                Klinik am Zuckerberg   0.472796  91.350649  90.922078
# 9                      Klinikum Peine   0.275747  62.317241  67.379310
# 10               Klinikum Wahrendorff   0.165236  45.723810  47.295238
# 11                 Klinikum Wolfsburg   0.215484  58.064655  62.245690
# 12               Krankenhaus Buchholz   0.218212  45.631148  51.368852
# 13                 Krankenhaus Winsen   0.211417  59.674419  61.627907
# 14     Psychiatrische Klinik Lüneburg   0.079971  30.153846  30.769231
# 15                      Sophienklinik   0.287036  61.922078  64.961039
# 16            St. Martini Krankenhaus   0.395636  74.111111  76.761905
#
#     Behandlung  Verwaltung  Ausstattung  Fach_arten  Rezension_zahl
# 0    33.337209   34.116279    32.610465           6             172
# 1    76.173611   69.034722    66.701389           7             144
# 2    69.854772   55.095436    62.414938          25             241
# 3    86.408163   87.816327    81.000000           8              49
# 4    63.959350   56.130081    57.219512          14             123
# 5    59.403226   55.693548    57.580645          18             124
# 6    81.773438   75.835938    75.335938          12             128
# 7    64.135593   50.635593    41.855932          16             118
# 8    92.649351   89.649351    90.090909          11              77
# 9    71.282759   64.634483    55.924138          18             145
# 10   43.847619   46.990476    51.438095           4             105
# 11   67.241379   51.336207    58.961207          19             232
# 12   55.204918   49.754098    46.500000          17             122
# 13   69.383721   60.127907    58.953488          14              86
# 14   35.250000   30.788462    33.365385           4              52
# 15   74.506494   62.831169    56.311688          10              77
# 16   80.460317   73.650794    68.365079          14              63

# %%
df_kliniks.columns
# Out:
# Index(['Name der Klinik', 'Polaritiy', 'Gesamt', 'Qualität', 'Behandlung',
#        'Verwaltung', 'Ausstattung', 'Fach_arten', 'Rezension_zahl'],
#       dtype='object')

# %%
df_model=df_kliniks[['Polaritiy', 'Gesamt', 'Qualität', 'Behandlung',
       'Verwaltung', 'Ausstattung', 'Rezension_zahl', 'Fach_arten']]
df_model.head()
# Out:
#    Polaritiy     Gesamt   Qualität  Behandlung  Verwaltung  Ausstattung  \
# 0   0.070400  34.319767  37.581395   33.337209   34.116279    32.610465
# 1   0.274780  70.861111  74.555556   76.173611   69.034722    66.701389
# 2   0.235991  60.165975  65.157676   69.854772   55.095436    62.414938
# 3   0.449850  84.367347  85.040816   86.408163   87.816327    81.000000
# 4   0.261306  56.910569  59.349593   63.959350   56.130081    57.219512
#
#    Rezension_zahl  Fach_arten
# 0             172           6
# 1             144           7
# 2             241          25
# 3              49           8
# 4             123          14

# %%
# set number of clusters
kclusters = 4

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_model)

# %%
# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([1, 1, 2, 0, 1, 1, 1, 1, 0, 1, 1, 2, 1, 0, 3, 0, 0], dtype=int32)

# %%
df_kliniks.insert(9, 'Cluster Labels', kmeans.labels_)
df_kliniks
# Out:
#                       Name der Klinik  Polaritiy     Gesamt   Qualität  \
# 0           AMEOS Klinikum Hildesheim   0.070400  34.319767  37.581395
# 1    AMEOS Klinikum Seepark Geestland   0.274780  70.861111  74.555556
# 2           DIAKOVERE Henriettenstift   0.235991  60.165975  65.157676
# 3          Eilenriede Klinik Hannover   0.449850  84.367347  85.040816
# 4              HELIOS Klinik Cuxhaven   0.261306  56.910569  59.349593
# 5         Helios Kliniken Mittelweser   0.256709  54.572581  56.185484
# 6         Herzogin Elisabeth Hospital   0.371762  79.179688  78.414062
# 7   KRH Klinikum Agness Karll Laatzen   0.184622  48.610169  57.076271
# 8                Klinik am Zuckerberg   0.472796  91.350649  90.922078
# 9                      Klinikum Peine   0.275747  62.317241  67.379310
# 10               Klinikum Wahrendorff   0.165236  45.723810  47.295238
# 11                 Klinikum Wolfsburg   0.215484  58.064655  62.245690
# 12               Krankenhaus Buchholz   0.218212  45.631148  51.368852
# 13                 Krankenhaus Winsen   0.211417  59.674419  61.627907
# 14     Psychiatrische Klinik Lüneburg   0.079971  30.153846  30.769231
# 15                      Sophienklinik   0.287036  61.922078  64.961039
# 16            St. Martini Krankenhaus   0.395636  74.111111  76.761905
#
#     Behandlung  Verwaltung  Ausstattung  Fach_arten  Rezension_zahl  \
# 0    33.337209   34.116279    32.610465           6             172
# 1    76.173611   69.034722    66.701389           7             144
# 2    69.854772   55.095436    62.414938          25             241
# 3    86.408163   87.816327    81.000000           8              49
# 4    63.959350   56.130081    57.219512          14             123
# 5    59.403226   55.693548    57.580645          18             124
# 6    81.773438   75.835938    75.335938          12             128
# 7    64.135593   50.635593    41.855932          16             118
# 8    92.649351   89.649351    90.090909          11              77
# 9    71.282759   64.634483    55.924138          18             145
# 10   43.847619   46.990476    51.438095           4             105
# 11   67.241379   51.336207    58.961207          19             232
# 12   55.204918   49.754098    46.500000          17             122
# 13   69.383721   60.127907    58.953488          14              86
# 14   35.250000   30.788462    33.365385           4              52
# 15   74.506494   62.831169    56.311688          10              77
# 16   80.460317   73.650794    68.365079          14              63
#
#     Cluster Labels
# 0                1
# 1                1
# 2                2
# 3                0
# 4                1
# 5                1
# 6                1
# 7                1
# 8                0
# 9                1
# 10               1
# 11               2
# 12               1
# 13               0
# 14               3
# 15               0
# 16               0

# %%
df_kliniks.describe().loc['mean']
# Out:
# Polaritiy           0.260409
# Gesamt             59.878598
# Qualität           62.746594
# Behandlung         66.168936
# Verwaltung         59.654169
# Ausstattung        58.507577
# Fach_arten         12.764706
# Rezension_zahl    121.058824
# Cluster Labels      0.941176
# Name: mean, dtype: float64

# %%
plt.figure(figsize=(6, 6))
sns.histplot(df_kliniks["Cluster Labels"], bins=4)
# Out:
# <AxesSubplot:xlabel='Cluster Labels', ylabel='Count'>

# %%
df_klinikClusters=df_kliniks['Cluster Labels'].value_counts().to_frame()
df_klinikClusters
# Out:
#    Cluster Labels
# 1               9
# 0               5
# 2               2
# 3               1

# %%
df_klinikClusters.index=["2.Group","1.Group","3.Group","4.Group"]

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
#explode_list = [0, 0, 0, 0, 0] # ratio for each continent with which to offset each wedge.

df_klinikClusters['Cluster Labels'].plot(kind='pie',
                            figsize=(15, 6),
                             
                            startangle=90,    
                            shadow=True,       
                                     # turn off labels on pie chart
                            pctdistance=1.1,    # the ratio between the center of each pie slice and the start of the text generated by autopct 
                            colors=colors_list,  # add custom colors
                            #explode=explode_list # 'explode' lowest 3 continents
                            )

# scale the title up by 12% to match pctdistance
plt.title('Clusters', y=1.12) 

plt.axis('equal') 

# add legend
#plt.legend(labels=df_gesamt.index, loc='upper left') 

plt.show()

# %%
df_kliniks.sort_values('Cluster Labels')
# Out:
#                       Name der Klinik  Polaritiy     Gesamt   Qualität  \
# 8                Klinik am Zuckerberg   0.472796  91.350649  90.922078
# 13                 Krankenhaus Winsen   0.211417  59.674419  61.627907
# 15                      Sophienklinik   0.287036  61.922078  64.961039
# 16            St. Martini Krankenhaus   0.395636  74.111111  76.761905
# 3          Eilenriede Klinik Hannover   0.449850  84.367347  85.040816
# 4              HELIOS Klinik Cuxhaven   0.261306  56.910569  59.349593
# 5         Helios Kliniken Mittelweser   0.256709  54.572581  56.185484
# 6         Herzogin Elisabeth Hospital   0.371762  79.179688  78.414062
# 7   KRH Klinikum Agness Karll Laatzen   0.184622  48.610169  57.076271
# 9                      Klinikum Peine   0.275747  62.317241  67.379310
# 10               Klinikum Wahrendorff   0.165236  45.723810  47.295238
# 12               Krankenhaus Buchholz   0.218212  45.631148  51.368852
# 1    AMEOS Klinikum Seepark Geestland   0.274780  70.861111  74.555556
# 0           AMEOS Klinikum Hildesheim   0.070400  34.319767  37.581395
# 2           DIAKOVERE Henriettenstift   0.235991  60.165975  65.157676
# 11                 Klinikum Wolfsburg   0.215484  58.064655  62.245690
# 14     Psychiatrische Klinik Lüneburg   0.079971  30.153846  30.769231
#
#     Behandlung  Verwaltung  Ausstattung  Fach_arten  Rezension_zahl  \
# 8    92.649351   89.649351    90.090909          11              77
# 13   69.383721   60.127907    58.953488          14              86
# 15   74.506494   62.831169    56.311688          10              77
# 16   80.460317   73.650794    68.365079          14              63
# 3    86.408163   87.816327    81.000000           8              49
# 4    63.959350   56.130081    57.219512          14             123
# 5    59.403226   55.693548    57.580645          18             124
# 6    81.773438   75.835938    75.335938          12             128
# 7    64.135593   50.635593    41.855932          16             118
# 9    71.282759   64.634483    55.924138          18             145
# 10   43.847619   46.990476    51.438095           4             105
# 12   55.204918   49.754098    46.500000          17             122
# 1    76.173611   69.034722    66.701389           7             144
# 0    33.337209   34.116279    32.610465           6             172
# 2    69.854772   55.095436    62.414938          25             241
# 11   67.241379   51.336207    58.961207          19             232
# 14   35.250000   30.788462    33.365385           4              52
#
#     Cluster Labels
# 8                0
# 13               0
# 15               0
# 16               0
# 3                0
# 4                1
# 5                1
# 6                1
# 7                1
# 9                1
# 10               1
# 12               1
# 1                1
# 0                1
# 2                2
# 11               2
# 14               3

# %% [markdown]
# <h1 align=center><font size = 4, color = blue>Gruppen</font></h1>

# %%
df_kliniks[df_kliniks["Cluster Labels"]==0]
# Out:
#                Name der Klinik  Polaritiy     Gesamt   Qualität  Behandlung  \
# 3   Eilenriede Klinik Hannover   0.449850  84.367347  85.040816   86.408163
# 8         Klinik am Zuckerberg   0.472796  91.350649  90.922078   92.649351
# 13          Krankenhaus Winsen   0.211417  59.674419  61.627907   69.383721
# 15               Sophienklinik   0.287036  61.922078  64.961039   74.506494
# 16     St. Martini Krankenhaus   0.395636  74.111111  76.761905   80.460317
#
#     Verwaltung  Ausstattung  Fach_arten  Rezension_zahl  Cluster Labels
# 3    87.816327    81.000000           8              49               0
# 8    89.649351    90.090909          11              77               0
# 13   60.127907    58.953488          14              86               0
# 15   62.831169    56.311688          10              77               0
# 16   73.650794    68.365079          14              63               0

# %%
df_kliniks[df_kliniks["Cluster Labels"]==0].groupby(['Cluster Labels'],as_index=False).mean()
# Out:
#    Cluster Labels  Polaritiy     Gesamt   Qualität  Behandlung  Verwaltung  \
# 0               0   0.363347  74.285121  75.862749   80.681609   74.815109
#
#    Ausstattung  Fach_arten  Rezension_zahl
# 0    70.944233        11.4            70.4

# %%
df_kliniks.describe().loc['mean']
# Out:
# Polaritiy           0.260409
# Gesamt             59.878598
# Qualität           62.746594
# Behandlung         66.168936
# Verwaltung         59.654169
# Ausstattung        58.507577
# Fach_arten         12.764706
# Rezension_zahl    121.058824
# Cluster Labels      0.941176
# Name: mean, dtype: float64

# %% [markdown]
# ### Gruppe-1:
#  - Hohes Like-Level
#  - Geringe Popularität

# %%
df_kliniks[df_kliniks["Cluster Labels"]==1]
# Out:
#                       Name der Klinik  Polaritiy     Gesamt   Qualität  \
# 0           AMEOS Klinikum Hildesheim   0.070400  34.319767  37.581395
# 1    AMEOS Klinikum Seepark Geestland   0.274780  70.861111  74.555556
# 4              HELIOS Klinik Cuxhaven   0.261306  56.910569  59.349593
# 5         Helios Kliniken Mittelweser   0.256709  54.572581  56.185484
# 6         Herzogin Elisabeth Hospital   0.371762  79.179688  78.414062
# 7   KRH Klinikum Agness Karll Laatzen   0.184622  48.610169  57.076271
# 9                      Klinikum Peine   0.275747  62.317241  67.379310
# 10               Klinikum Wahrendorff   0.165236  45.723810  47.295238
# 12               Krankenhaus Buchholz   0.218212  45.631148  51.368852
#
#     Behandlung  Verwaltung  Ausstattung  Fach_arten  Rezension_zahl  \
# 0    33.337209   34.116279    32.610465           6             172
# 1    76.173611   69.034722    66.701389           7             144
# 4    63.959350   56.130081    57.219512          14             123
# 5    59.403226   55.693548    57.580645          18             124
# 6    81.773438   75.835938    75.335938          12             128
# 7    64.135593   50.635593    41.855932          16             118
# 9    71.282759   64.634483    55.924138          18             145
# 10   43.847619   46.990476    51.438095           4             105
# 12   55.204918   49.754098    46.500000          17             122
#
#     Cluster Labels
# 0                1
# 1                1
# 4                1
# 5                1
# 6                1
# 7                1
# 9                1
# 10               1
# 12               1

# %%
df_kliniks[df_kliniks["Cluster Labels"]==1].groupby(['Cluster Labels'],as_index=False).mean()
# Out:
#    Cluster Labels  Polaritiy     Gesamt  Qualität  Behandlung  Verwaltung  \
# 0               1   0.230975  55.347343  58.80064    61.01308   55.869469
#
#    Ausstattung  Fach_arten  Rezension_zahl
# 0    53.907346   12.444444      131.222222

# %%
df_kliniks.describe().loc['mean']
# Out:
# Polaritiy           0.260409
# Gesamt             59.878598
# Qualität           62.746594
# Behandlung         66.168936
# Verwaltung         59.654169
# Ausstattung        58.507577
# Fach_arten         12.764706
# Rezension_zahl    121.058824
# Cluster Labels      0.941176
# Name: mean, dtype: float64

# %% [markdown]
# ## Gruppe-2:
# - Durchschnittliche Like-Level
# - Durchschnittliche Popularität

# %%
df_kliniks[df_kliniks["Cluster Labels"]==2]
# Out:
#               Name der Klinik  Polaritiy     Gesamt   Qualität  Behandlung  \
# 2   DIAKOVERE Henriettenstift   0.235991  60.165975  65.157676   69.854772
# 11         Klinikum Wolfsburg   0.215484  58.064655  62.245690   67.241379
#
#     Verwaltung  Ausstattung  Fach_arten  Rezension_zahl  Cluster Labels
# 2    55.095436    62.414938          25             241               2
# 11   51.336207    58.961207          19             232               2

# %%
df_kliniks[df_kliniks["Cluster Labels"]==2].groupby(['Cluster Labels'],as_index=False).mean()
# Out:
#    Cluster Labels  Polaritiy     Gesamt   Qualität  Behandlung  Verwaltung  \
# 0               2   0.225737  59.115315  63.701683   68.548076   53.215821
#
#    Ausstattung  Fach_arten  Rezension_zahl
# 0    60.688072        22.0           236.5

# %%
df_kliniks.describe().loc['mean']
# Out:
# Polaritiy           0.260409
# Gesamt             59.878598
# Qualität           62.746594
# Behandlung         66.168936
# Verwaltung         59.654169
# Ausstattung        58.507577
# Fach_arten         12.764706
# Rezension_zahl    121.058824
# Cluster Labels      0.941176
# Name: mean, dtype: float64

# %% [markdown]
# ### Gruppe-3:
# - Durchschnittliche Like-Level
# - Hoche Popularität

# %%
df_kliniks[df_kliniks["Cluster Labels"]==3]
# Out:
#                    Name der Klinik  Polaritiy     Gesamt   Qualität  \
# 14  Psychiatrische Klinik Lüneburg   0.079971  30.153846  30.769231
#
#     Behandlung  Verwaltung  Ausstattung  Fach_arten  Rezension_zahl  \
# 14       35.25   30.788462    33.365385           4              52
#
#     Cluster Labels
# 14               3

# %%
df_kliniks.describe().loc['mean']
# Out:
# Polaritiy           0.260409
# Gesamt             59.878598
# Qualität           62.746594
# Behandlung         66.168936
# Verwaltung         59.654169
# Ausstattung        58.507577
# Fach_arten         12.764706
# Rezension_zahl    121.058824
# Cluster Labels      0.941176
# Name: mean, dtype: float64

# %% [markdown]
# ### Gruppe-4:
#  - Niedriges Like-Level
#  - Niedrige Popularität

# %% [markdown]
# ## Hinzufügen von Gruppenlabels zum Dataset

# %% [markdown]
# ### Google Dataset

# %%
klinik_bewertungen_google_afterModeling=pd.read_csv("../Exploratory Data Analysis/GoogleMaps/klinik_bewertungen_google_afterAnalysis.csv")

# %%
klinik_bewertungen_google_afterModeling.groupby(['Name der Klinik'],as_index=False).mean()["Name der Klinik"].to_list()
# Out:
# ['AMEOS Klinikum Hildesheim',
#  'AMEOS Klinikum Seepark Geestland',
#  'DIAKOVERE Henriettenstift',
#  'Eilenriede Klinik Hannover',
#  'HELIOS Klinik Cuxhaven',
#  'Helios Kliniken Mittelweser',
#  'Herzogin Elisabeth Hospital',
#  'KRH Klinikum Agnes Karll Laatzen',
#  'Klinik Am Zuckerberg GmbH',
#  'Klinikum Peine gGmbH',
#  'Klinikum Wahrendorff',
#  'Klinikum Wolfsburg in Wolfsburg',
#  'Krankenhaus Buchholz',
#  'Krankenhaus Winsen',
#  'Psychiatrische Klinik Lüneburg',
#  'Sophienklinik GmbH',
#  'St. Martini Krankenhaus']

# %%
klinik_cluster_df=df_kliniks[["Name der Klinik","Cluster Labels"]]
klinik_cluster_df["Name der Klinik"]=klinik_bewertungen_google_afterModeling.groupby(['Name der Klinik'],as_index=False).mean()["Name der Klinik"].to_list()
klinik_cluster_df
# Out:
# <ipython-input-33-5f4ffd6a3ef6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   klinik_cluster_df["Name der Klinik"]=klinik_bewertungen_google_afterModeling.groupby(['Name der Klinik'],as_index=False).mean()["Name der Klinik"].to_list()
#                      Name der Klinik  Cluster Labels
# 0          AMEOS Klinikum Hildesheim               1
# 1   AMEOS Klinikum Seepark Geestland               1
# 2          DIAKOVERE Henriettenstift               2
# 3         Eilenriede Klinik Hannover               0
# 4             HELIOS Klinik Cuxhaven               1
# 5        Helios Kliniken Mittelweser               1
# 6        Herzogin Elisabeth Hospital               1
# 7   KRH Klinikum Agnes Karll Laatzen               1
# 8          Klinik Am Zuckerberg GmbH               0
# 9               Klinikum Peine gGmbH               1
# 10              Klinikum Wahrendorff               1
# 11   Klinikum Wolfsburg in Wolfsburg               2
# 12              Krankenhaus Buchholz               1
# 13                Krankenhaus Winsen               0
# 14    Psychiatrische Klinik Lüneburg               3
# 15                Sophienklinik GmbH               0
# 16           St. Martini Krankenhaus               0

# %%
klinik_cluster_df.iloc[15,0]
# Out:
# 'Sophienklinik GmbH'

# %%
klinik_name_list=klinik_bewertungen_google_afterModeling["Name der Klinik"].to_list()
cluster=[]

for i in range(len(klinik_bewertungen_google_afterModeling["Name der Klinik"].to_list())):
    added=False
    for j in range(17):
        if klinik_name_list[i]==klinik_cluster_df.iloc[j,0]:
            added=True
            cluster.append(klinik_cluster_df.iloc[j,1])
    if not added:
        print(klinik_name_list[i])

# %%
klinik_bewertungen_google_afterModeling["Gruppe"]=cluster
klinik_bewertungen_google_afterModeling
# Out:
#                      Name der Klinik  \
# 0        Herzogin Elisabeth Hospital
# 1        Herzogin Elisabeth Hospital
# 2        Herzogin Elisabeth Hospital
# 3        Herzogin Elisabeth Hospital
# 4        Herzogin Elisabeth Hospital
# ...                              ...
# 1482  Psychiatrische Klinik Lüneburg
# 1483  Psychiatrische Klinik Lüneburg
# 1484  Psychiatrische Klinik Lüneburg
# 1485  Psychiatrische Klinik Lüneburg
# 1486  Psychiatrische Klinik Lüneburg
#
#                                     Textuelle Bewertung  Sternebewertung  \
# 0     Vor der Corona Pandemie hätte ich jeden zugest...                2
# 1     Tolles Krankenhaus,  trotzdem bin ich lieber g...                4
# 2     Lungenembolie!**Ein Tag ITS, phantastische Für...                5
# 3                      Alles sehr gut. Volle Punktzahl!                5
# 4     Ich werde nie wieder in ein anderes Krankenhau...                5
# ...                                                 ...              ...
# 1482  Ratiopharms Rache... leicht anmaßende Azubis u...                1
# 1483                                     Es war schlimm                1
# 1484                                   Menschenunwürdig                1
# 1485                             Nicht gute Mitarbeiter                3
# 1486  (Übersetzt von Google) Oben!!****(Original)**T...                5
#
#       Polaritiy  Subjectivity  year  Likes  positive  Gruppe
# 0      0.283333           0.0  2021      1         0       1
# 1      0.500000           0.0  2020      1         1       1
# 2      0.333333           0.0  2021      1         1       1
# 3      0.500000           0.0  2018      4         1       1
# 4      0.212500           0.0  2021      1         0       1
# ...         ...           ...   ...    ...       ...     ...
# 1482   1.000000           0.0  2017      1         1       3
# 1483  -1.000000           0.0  2019      0         0       3
# 1484  -1.000000           0.0  2019      0         0       3
# 1485  -0.500000           0.0  2016      0         0       3
# 1486   0.500000           0.0  2017      0         1       3
#
# [1487 rows x 9 columns]

# %%
#klinik_bewertungen_google_afterModeling.to_csv('klinik_bewertungen_google_afterModeling.csv', index=False)

# %% [markdown]
# ### KlinikbewertungenDe Dataset

# %%
klinik_bewertungen_afterModeling=pd.read_csv("../Exploratory Data Analysis/KlinikBewertungen/klinik_bewertungen_afterAnalysis.csv")

# %%
klinik_cluster_df=df_kliniks[["Name der Klinik","Cluster Labels"]]

# %%
klinik_name_list=klinik_bewertungen_afterModeling["Name der Klinik"].to_list()
cluster=[]

for i in range(len(klinik_bewertungen_afterModeling["Name der Klinik"].to_list())):
    added=False
    for j in range(17):
        if klinik_name_list[i]==klinik_cluster_df.iloc[j,0]:
            added=True
            cluster.append(klinik_cluster_df.iloc[j,1])
    if not added:
        print(klinik_name_list[i])

# %%
klinik_bewertungen_afterModeling["Gruppe"]=cluster
klinik_bewertungen_afterModeling
# Out:
#                      Name der Klinik                            Titel  \
# 0        Herzogin Elisabeth Hospital                      Superklinik
# 1        Herzogin Elisabeth Hospital       Kranken- oder Hotelzimmer?
# 2        Herzogin Elisabeth Hospital                          Knie OP
# 3        Herzogin Elisabeth Hospital         Beste Erfahrungen im HEH
# 4        Herzogin Elisabeth Hospital    Superkompetent und freundlich
# ...                              ...                              ...
# 2053  Psychiatrische Klinik Lüneburg             Hilft nur in Krisen!
# 2054  Psychiatrische Klinik Lüneburg  Mir gings schlechter als vorher
# 2055  Psychiatrische Klinik Lüneburg      Eine positive Überraschung!
# 2056  Psychiatrische Klinik Lüneburg      Tagesklinik Uelzener Straße
# 2057  Psychiatrische Klinik Lüneburg         Eine einzige Katastrophe
#
#            Datum         Fachbereich  \
# 0     2021-06-07          Orthopädie
# 1     2021-05-25     Unfallchirurgie
# 2     2021-05-11          Orthopädie
# 3     2021-05-09           Chirurgie
# 4     2021-05-07      Gefäßchirurgie
# ...          ...                 ...
# 2053  2013-07-23  Kind/Jugend-Psych.
# 2054  2013-03-19         Psychiatrie
# 2055  2009-12-05         Psychiatrie
# 2056  2009-10-25         Psychiatrie
# 2057  2009-01-26  Kind/Jugend-Psych.
#
#                                       Erfahrungsbericht  Polaritiy  \
# 0     Bestens durchorganisiert.gutes Personal geht i...   0.000000
# 1     Bin nach einem Autounfall im HEH gewesen und h...   0.340000
# 2     Wurde bereits im Sept. 2020 am Knie operiert. ...   0.242857
# 3     Da ich zeit meines Lebens noch nie einen Krank...   0.536111
# 4     Das gesamte Personal von der Notaufnahme über ...   0.428571
# ...                                                 ...        ...
# 2053  Ich war in 2 verschiedenen Häusern. (ehm.) Hau...   0.333333
# 2054  Ich war vor kuzen Patientrin auf der Station 1...   0.115833
# 2055  Ich befinde mich seit einigen Wochen in Behand...   0.611333
# 2056  Ich kann mich Angie nur anschließen! Diese Tag...  -0.175000
# 2057  Hallo,diese Klinik ist eine einzige Katastroph...  -0.385714
#
#       Subjectivity  year  month  day  Gesamt  Qualität  Behandlung  \
# 0         0.000000  2021      6    7   100.0     100.0       100.0
# 1         0.000000  2021      5   25   100.0     100.0       100.0
# 2         0.000000  2021      5   11   100.0     100.0       100.0
# 3         0.000000  2021      5    9   100.0     100.0       100.0
# 4         0.000000  2021      5    7   100.0     100.0       100.0
# ...            ...   ...    ...  ...     ...       ...         ...
# 2053      0.000000  2013      7   23    33.0      33.0        67.0
# 2054      0.050000  2013      3   19     0.0       0.0         0.0
# 2055      0.066667  2009     12    5   100.0     100.0        67.0
# 2056      0.083333  2009     10   25     0.0       0.0         0.0
# 2057      0.000000  2009      1   26     0.0       0.0         0.0
#
#       Verwaltung  Ausstattung  positive  Gruppe
# 0          100.0        100.0         1       1
# 1          100.0         67.0         1       1
# 2          100.0        100.0         1       1
# 3           67.0        100.0         1       1
# 4          100.0         67.0         1       1
# ...          ...          ...       ...     ...
# 2053         0.0         33.0         1       3
# 2054         0.0          0.0         1       3
# 2055       100.0        100.0         1       3
# 2056         0.0          0.0         0       3
# 2057         0.0          0.0         0       3
#
# [2058 rows x 17 columns]

# %%
#klinik_bewertungen_afterModeling.to_csv('klinik_bewertungen_afterModeling.csv', index=False)

# %% [markdown]
# ## Hinzufügen einer Indexspalte

# %% [markdown]
# ### Google Dataset

# %%
klinik_bewertungen_google_afterModeling.head(1)
# Out:
#                Name der Klinik  \
# 0  Herzogin Elisabeth Hospital
#
#                                  Textuelle Bewertung  Sternebewertung  \
# 0  Vor der Corona Pandemie hätte ich jeden zugest...                2
#
#    Polaritiy  Subjectivity  year  Likes  positive  Gruppe
# 0   0.283333           0.0  2021      1         0       1

# %%
klinik_bewertungen_google_afterModeling['index'] = klinik_bewertungen_google_afterModeling.index
klinik_bewertungen_google_afterModeling
# Out:
#                      Name der Klinik  \
# 0        Herzogin Elisabeth Hospital
# 1        Herzogin Elisabeth Hospital
# 2        Herzogin Elisabeth Hospital
# 3        Herzogin Elisabeth Hospital
# 4        Herzogin Elisabeth Hospital
# ...                              ...
# 1482  Psychiatrische Klinik Lüneburg
# 1483  Psychiatrische Klinik Lüneburg
# 1484  Psychiatrische Klinik Lüneburg
# 1485  Psychiatrische Klinik Lüneburg
# 1486  Psychiatrische Klinik Lüneburg
#
#                                     Textuelle Bewertung  Sternebewertung  \
# 0     Vor der Corona Pandemie hätte ich jeden zugest...                2
# 1     Tolles Krankenhaus,  trotzdem bin ich lieber g...                4
# 2     Lungenembolie!**Ein Tag ITS, phantastische Für...                5
# 3                      Alles sehr gut. Volle Punktzahl!                5
# 4     Ich werde nie wieder in ein anderes Krankenhau...                5
# ...                                                 ...              ...
# 1482  Ratiopharms Rache... leicht anmaßende Azubis u...                1
# 1483                                     Es war schlimm                1
# 1484                                   Menschenunwürdig                1
# 1485                             Nicht gute Mitarbeiter                3
# 1486  (Übersetzt von Google) Oben!!****(Original)**T...                5
#
#       Polaritiy  Subjectivity  year  Likes  positive  Gruppe  index
# 0      0.283333           0.0  2021      1         0       1      0
# 1      0.500000           0.0  2020      1         1       1      1
# 2      0.333333           0.0  2021      1         1       1      2
# 3      0.500000           0.0  2018      4         1       1      3
# 4      0.212500           0.0  2021      1         0       1      4
# ...         ...           ...   ...    ...       ...     ...    ...
# 1482   1.000000           0.0  2017      1         1       3   1482
# 1483  -1.000000           0.0  2019      0         0       3   1483
# 1484  -1.000000           0.0  2019      0         0       3   1484
# 1485  -0.500000           0.0  2016      0         0       3   1485
# 1486   0.500000           0.0  2017      0         1       3   1486
#
# [1487 rows x 10 columns]

# %%
new_cols= ['index','Name der Klinik', 'Textuelle Bewertung', 'Sternebewertung',
       'Polaritiy', 'Subjectivity', 'year', 'Likes', 'positive', 'Gruppe' ]

# %%
klinik_bewertungen_google_afterModeling = klinik_bewertungen_google_afterModeling.reindex(columns=new_cols)
klinik_bewertungen_google_afterModeling
# Out:
#       index                 Name der Klinik  \
# 0         0     Herzogin Elisabeth Hospital
# 1         1     Herzogin Elisabeth Hospital
# 2         2     Herzogin Elisabeth Hospital
# 3         3     Herzogin Elisabeth Hospital
# 4         4     Herzogin Elisabeth Hospital
# ...     ...                             ...
# 1482   1482  Psychiatrische Klinik Lüneburg
# 1483   1483  Psychiatrische Klinik Lüneburg
# 1484   1484  Psychiatrische Klinik Lüneburg
# 1485   1485  Psychiatrische Klinik Lüneburg
# 1486   1486  Psychiatrische Klinik Lüneburg
#
#                                     Textuelle Bewertung  Sternebewertung  \
# 0     Vor der Corona Pandemie hätte ich jeden zugest...                2
# 1     Tolles Krankenhaus,  trotzdem bin ich lieber g...                4
# 2     Lungenembolie!**Ein Tag ITS, phantastische Für...                5
# 3                      Alles sehr gut. Volle Punktzahl!                5
# 4     Ich werde nie wieder in ein anderes Krankenhau...                5
# ...                                                 ...              ...
# 1482  Ratiopharms Rache... leicht anmaßende Azubis u...                1
# 1483                                     Es war schlimm                1
# 1484                                   Menschenunwürdig                1
# 1485                             Nicht gute Mitarbeiter                3
# 1486  (Übersetzt von Google) Oben!!****(Original)**T...                5
#
#       Polaritiy  Subjectivity  year  Likes  positive  Gruppe
# 0      0.283333           0.0  2021      1         0       1
# 1      0.500000           0.0  2020      1         1       1
# 2      0.333333           0.0  2021      1         1       1
# 3      0.500000           0.0  2018      4         1       1
# 4      0.212500           0.0  2021      1         0       1
# ...         ...           ...   ...    ...       ...     ...
# 1482   1.000000           0.0  2017      1         1       3
# 1483  -1.000000           0.0  2019      0         0       3
# 1484  -1.000000           0.0  2019      0         0       3
# 1485  -0.500000           0.0  2016      0         0       3
# 1486   0.500000           0.0  2017      0         1       3
#
# [1487 rows x 10 columns]

# %% [markdown]
# ### KlinikbewertungenDe Dataset

# %%
klinik_bewertungen_afterModeling.head(1)
# Out:
#                Name der Klinik        Titel       Datum Fachbereich  \
# 0  Herzogin Elisabeth Hospital  Superklinik  2021-06-07  Orthopädie
#
#                                    Erfahrungsbericht  Polaritiy  Subjectivity  \
# 0  Bestens durchorganisiert.gutes Personal geht i...        0.0           0.0
#
#    year  month  day  Gesamt  Qualität  Behandlung  Verwaltung  Ausstattung  \
# 0  2021      6    7   100.0     100.0       100.0       100.0        100.0
#
#    positive  Gruppe
# 0         1       1

# %%
klinik_bewertungen_afterModeling['index'] = klinik_bewertungen_afterModeling.index
klinik_bewertungen_afterModeling
# Out:
#                      Name der Klinik                            Titel  \
# 0        Herzogin Elisabeth Hospital                      Superklinik
# 1        Herzogin Elisabeth Hospital       Kranken- oder Hotelzimmer?
# 2        Herzogin Elisabeth Hospital                          Knie OP
# 3        Herzogin Elisabeth Hospital         Beste Erfahrungen im HEH
# 4        Herzogin Elisabeth Hospital    Superkompetent und freundlich
# ...                              ...                              ...
# 2053  Psychiatrische Klinik Lüneburg             Hilft nur in Krisen!
# 2054  Psychiatrische Klinik Lüneburg  Mir gings schlechter als vorher
# 2055  Psychiatrische Klinik Lüneburg      Eine positive Überraschung!
# 2056  Psychiatrische Klinik Lüneburg      Tagesklinik Uelzener Straße
# 2057  Psychiatrische Klinik Lüneburg         Eine einzige Katastrophe
#
#            Datum         Fachbereich  \
# 0     2021-06-07          Orthopädie
# 1     2021-05-25     Unfallchirurgie
# 2     2021-05-11          Orthopädie
# 3     2021-05-09           Chirurgie
# 4     2021-05-07      Gefäßchirurgie
# ...          ...                 ...
# 2053  2013-07-23  Kind/Jugend-Psych.
# 2054  2013-03-19         Psychiatrie
# 2055  2009-12-05         Psychiatrie
# 2056  2009-10-25         Psychiatrie
# 2057  2009-01-26  Kind/Jugend-Psych.
#
#                                       Erfahrungsbericht  Polaritiy  \
# 0     Bestens durchorganisiert.gutes Personal geht i...   0.000000
# 1     Bin nach einem Autounfall im HEH gewesen und h...   0.340000
# 2     Wurde bereits im Sept. 2020 am Knie operiert. ...   0.242857
# 3     Da ich zeit meines Lebens noch nie einen Krank...   0.536111
# 4     Das gesamte Personal von der Notaufnahme über ...   0.428571
# ...                                                 ...        ...
# 2053  Ich war in 2 verschiedenen Häusern. (ehm.) Hau...   0.333333
# 2054  Ich war vor kuzen Patientrin auf der Station 1...   0.115833
# 2055  Ich befinde mich seit einigen Wochen in Behand...   0.611333
# 2056  Ich kann mich Angie nur anschließen! Diese Tag...  -0.175000
# 2057  Hallo,diese Klinik ist eine einzige Katastroph...  -0.385714
#
#       Subjectivity  year  month  day  Gesamt  Qualität  Behandlung  \
# 0         0.000000  2021      6    7   100.0     100.0       100.0
# 1         0.000000  2021      5   25   100.0     100.0       100.0
# 2         0.000000  2021      5   11   100.0     100.0       100.0
# 3         0.000000  2021      5    9   100.0     100.0       100.0
# 4         0.000000  2021      5    7   100.0     100.0       100.0
# ...            ...   ...    ...  ...     ...       ...         ...
# 2053      0.000000  2013      7   23    33.0      33.0        67.0
# 2054      0.050000  2013      3   19     0.0       0.0         0.0
# 2055      0.066667  2009     12    5   100.0     100.0        67.0
# 2056      0.083333  2009     10   25     0.0       0.0         0.0
# 2057      0.000000  2009      1   26     0.0       0.0         0.0
#
#       Verwaltung  Ausstattung  positive  Gruppe  index
# 0          100.0        100.0         1       1      0
# 1          100.0         67.0         1       1      1
# 2          100.0        100.0         1       1      2
# 3           67.0        100.0         1       1      3
# 4          100.0         67.0         1       1      4
# ...          ...          ...       ...     ...    ...
# 2053         0.0         33.0         1       3   2053
# 2054         0.0          0.0         1       3   2054
# 2055       100.0        100.0         1       3   2055
# 2056         0.0          0.0         0       3   2056
# 2057         0.0          0.0         0       3   2057
#
# [2058 rows x 18 columns]

# %%
new_cols= ['index','Name der Klinik', 'Titel', 'Datum', 'Fachbereich',
       'Erfahrungsbericht', 'Polaritiy', 'Subjectivity', 'year', 'month',
       'day', 'Gesamt', 'Qualität', 'Behandlung', 'Verwaltung',
       'Ausstattung', 'positive', 'Gruppe' ]

# %%
klinik_bewertungen_afterModeling = klinik_bewertungen_afterModeling.reindex(columns=new_cols)
klinik_bewertungen_afterModeling
# Out:
#       index                 Name der Klinik                            Titel  \
# 0         0     Herzogin Elisabeth Hospital                      Superklinik
# 1         1     Herzogin Elisabeth Hospital       Kranken- oder Hotelzimmer?
# 2         2     Herzogin Elisabeth Hospital                          Knie OP
# 3         3     Herzogin Elisabeth Hospital         Beste Erfahrungen im HEH
# 4         4     Herzogin Elisabeth Hospital    Superkompetent und freundlich
# ...     ...                             ...                              ...
# 2053   2053  Psychiatrische Klinik Lüneburg             Hilft nur in Krisen!
# 2054   2054  Psychiatrische Klinik Lüneburg  Mir gings schlechter als vorher
# 2055   2055  Psychiatrische Klinik Lüneburg      Eine positive Überraschung!
# 2056   2056  Psychiatrische Klinik Lüneburg      Tagesklinik Uelzener Straße
# 2057   2057  Psychiatrische Klinik Lüneburg         Eine einzige Katastrophe
#
#            Datum         Fachbereich  \
# 0     2021-06-07          Orthopädie
# 1     2021-05-25     Unfallchirurgie
# 2     2021-05-11          Orthopädie
# 3     2021-05-09           Chirurgie
# 4     2021-05-07      Gefäßchirurgie
# ...          ...                 ...
# 2053  2013-07-23  Kind/Jugend-Psych.
# 2054  2013-03-19         Psychiatrie
# 2055  2009-12-05         Psychiatrie
# 2056  2009-10-25         Psychiatrie
# 2057  2009-01-26  Kind/Jugend-Psych.
#
#                                       Erfahrungsbericht  Polaritiy  \
# 0     Bestens durchorganisiert.gutes Personal geht i...   0.000000
# 1     Bin nach einem Autounfall im HEH gewesen und h...   0.340000
# 2     Wurde bereits im Sept. 2020 am Knie operiert. ...   0.242857
# 3     Da ich zeit meines Lebens noch nie einen Krank...   0.536111
# 4     Das gesamte Personal von der Notaufnahme über ...   0.428571
# ...                                                 ...        ...
# 2053  Ich war in 2 verschiedenen Häusern. (ehm.) Hau...   0.333333
# 2054  Ich war vor kuzen Patientrin auf der Station 1...   0.115833
# 2055  Ich befinde mich seit einigen Wochen in Behand...   0.611333
# 2056  Ich kann mich Angie nur anschließen! Diese Tag...  -0.175000
# 2057  Hallo,diese Klinik ist eine einzige Katastroph...  -0.385714
#
#       Subjectivity  year  month  day  Gesamt  Qualität  Behandlung  \
# 0         0.000000  2021      6    7   100.0     100.0       100.0
# 1         0.000000  2021      5   25   100.0     100.0       100.0
# 2         0.000000  2021      5   11   100.0     100.0       100.0
# 3         0.000000  2021      5    9   100.0     100.0       100.0
# 4         0.000000  2021      5    7   100.0     100.0       100.0
# ...            ...   ...    ...  ...     ...       ...         ...
# 2053      0.000000  2013      7   23    33.0      33.0        67.0
# 2054      0.050000  2013      3   19     0.0       0.0         0.0
# 2055      0.066667  2009     12    5   100.0     100.0        67.0
# 2056      0.083333  2009     10   25     0.0       0.0         0.0
# 2057      0.000000  2009      1   26     0.0       0.0         0.0
#
#       Verwaltung  Ausstattung  positive  Gruppe
# 0          100.0        100.0         1       1
# 1          100.0         67.0         1       1
# 2          100.0        100.0         1       1
# 3           67.0        100.0         1       1
# 4          100.0         67.0         1       1
# ...          ...          ...       ...     ...
# 2053         0.0         33.0         1       3
# 2054         0.0          0.0         1       3
# 2055       100.0        100.0         1       3
# 2056         0.0          0.0         0       3
# 2057         0.0          0.0         0       3
#
# [2058 rows x 18 columns]

# %% [markdown]
# ## Spaltennamen bearbeiten

# %% [markdown]
# ### KlinikbewertungenDe Dataset

# %%
klinik_bewertungen_afterModeling=klinik_bewertungen_afterModeling.rename({'Name der Klinik':'Name'}, axis='columns')
klinik_bewertungen_afterModeling
# Out:
#       index                            Name                            Titel  \
# 0         0     Herzogin Elisabeth Hospital                      Superklinik
# 1         1     Herzogin Elisabeth Hospital       Kranken- oder Hotelzimmer?
# 2         2     Herzogin Elisabeth Hospital                          Knie OP
# 3         3     Herzogin Elisabeth Hospital         Beste Erfahrungen im HEH
# 4         4     Herzogin Elisabeth Hospital    Superkompetent und freundlich
# ...     ...                             ...                              ...
# 2053   2053  Psychiatrische Klinik Lüneburg             Hilft nur in Krisen!
# 2054   2054  Psychiatrische Klinik Lüneburg  Mir gings schlechter als vorher
# 2055   2055  Psychiatrische Klinik Lüneburg      Eine positive Überraschung!
# 2056   2056  Psychiatrische Klinik Lüneburg      Tagesklinik Uelzener Straße
# 2057   2057  Psychiatrische Klinik Lüneburg         Eine einzige Katastrophe
#
#            Datum         Fachbereich  \
# 0     2021-06-07          Orthopädie
# 1     2021-05-25     Unfallchirurgie
# 2     2021-05-11          Orthopädie
# 3     2021-05-09           Chirurgie
# 4     2021-05-07      Gefäßchirurgie
# ...          ...                 ...
# 2053  2013-07-23  Kind/Jugend-Psych.
# 2054  2013-03-19         Psychiatrie
# 2055  2009-12-05         Psychiatrie
# 2056  2009-10-25         Psychiatrie
# 2057  2009-01-26  Kind/Jugend-Psych.
#
#                                       Erfahrungsbericht  Polaritiy  \
# 0     Bestens durchorganisiert.gutes Personal geht i...   0.000000
# 1     Bin nach einem Autounfall im HEH gewesen und h...   0.340000
# 2     Wurde bereits im Sept. 2020 am Knie operiert. ...   0.242857
# 3     Da ich zeit meines Lebens noch nie einen Krank...   0.536111
# 4     Das gesamte Personal von der Notaufnahme über ...   0.428571
# ...                                                 ...        ...
# 2053  Ich war in 2 verschiedenen Häusern. (ehm.) Hau...   0.333333
# 2054  Ich war vor kuzen Patientrin auf der Station 1...   0.115833
# 2055  Ich befinde mich seit einigen Wochen in Behand...   0.611333
# 2056  Ich kann mich Angie nur anschließen! Diese Tag...  -0.175000
# 2057  Hallo,diese Klinik ist eine einzige Katastroph...  -0.385714
#
#       Subjectivity  year  month  day  Gesamt  Qualität  Behandlung  \
# 0         0.000000  2021      6    7   100.0     100.0       100.0
# 1         0.000000  2021      5   25   100.0     100.0       100.0
# 2         0.000000  2021      5   11   100.0     100.0       100.0
# 3         0.000000  2021      5    9   100.0     100.0       100.0
# 4         0.000000  2021      5    7   100.0     100.0       100.0
# ...            ...   ...    ...  ...     ...       ...         ...
# 2053      0.000000  2013      7   23    33.0      33.0        67.0
# 2054      0.050000  2013      3   19     0.0       0.0         0.0
# 2055      0.066667  2009     12    5   100.0     100.0        67.0
# 2056      0.083333  2009     10   25     0.0       0.0         0.0
# 2057      0.000000  2009      1   26     0.0       0.0         0.0
#
#       Verwaltung  Ausstattung  positive  Gruppe
# 0          100.0        100.0         1       1
# 1          100.0         67.0         1       1
# 2          100.0        100.0         1       1
# 3           67.0        100.0         1       1
# 4          100.0         67.0         1       1
# ...          ...          ...       ...     ...
# 2053         0.0         33.0         1       3
# 2054         0.0          0.0         1       3
# 2055       100.0        100.0         1       3
# 2056         0.0          0.0         0       3
# 2057         0.0          0.0         0       3
#
# [2058 rows x 18 columns]

# %%
klinik_bewertungen_afterModeling=klinik_bewertungen_afterModeling.rename({'Name':'name','Titel':'titel','Datum':'datum','Fachbereich':'fachbereich','Erfahrungsbericht':'komment', 'Polaritiy':'polarity','Subjectivity':'subjectivity','Gesamt':'gesamt',
       'Qualität':'qualität', 'Behandlung':'behandlung', 'Verwaltung':'verwaltung', 'Ausstattung':'ausstattung','Gruppe':'group'}, axis='columns')
klinik_bewertungen_afterModeling
# Out:
#       index                            name                            titel  \
# 0         0     Herzogin Elisabeth Hospital                      Superklinik
# 1         1     Herzogin Elisabeth Hospital       Kranken- oder Hotelzimmer?
# 2         2     Herzogin Elisabeth Hospital                          Knie OP
# 3         3     Herzogin Elisabeth Hospital         Beste Erfahrungen im HEH
# 4         4     Herzogin Elisabeth Hospital    Superkompetent und freundlich
# ...     ...                             ...                              ...
# 2053   2053  Psychiatrische Klinik Lüneburg             Hilft nur in Krisen!
# 2054   2054  Psychiatrische Klinik Lüneburg  Mir gings schlechter als vorher
# 2055   2055  Psychiatrische Klinik Lüneburg      Eine positive Überraschung!
# 2056   2056  Psychiatrische Klinik Lüneburg      Tagesklinik Uelzener Straße
# 2057   2057  Psychiatrische Klinik Lüneburg         Eine einzige Katastrophe
#
#            datum         fachbereich  \
# 0     2021-06-07          Orthopädie
# 1     2021-05-25     Unfallchirurgie
# 2     2021-05-11          Orthopädie
# 3     2021-05-09           Chirurgie
# 4     2021-05-07      Gefäßchirurgie
# ...          ...                 ...
# 2053  2013-07-23  Kind/Jugend-Psych.
# 2054  2013-03-19         Psychiatrie
# 2055  2009-12-05         Psychiatrie
# 2056  2009-10-25         Psychiatrie
# 2057  2009-01-26  Kind/Jugend-Psych.
#
#                                                 komment  polarity  \
# 0     Bestens durchorganisiert.gutes Personal geht i...  0.000000
# 1     Bin nach einem Autounfall im HEH gewesen und h...  0.340000
# 2     Wurde bereits im Sept. 2020 am Knie operiert. ...  0.242857
# 3     Da ich zeit meines Lebens noch nie einen Krank...  0.536111
# 4     Das gesamte Personal von der Notaufnahme über ...  0.428571
# ...                                                 ...       ...
# 2053  Ich war in 2 verschiedenen Häusern. (ehm.) Hau...  0.333333
# 2054  Ich war vor kuzen Patientrin auf der Station 1...  0.115833
# 2055  Ich befinde mich seit einigen Wochen in Behand...  0.611333
# 2056  Ich kann mich Angie nur anschließen! Diese Tag... -0.175000
# 2057  Hallo,diese Klinik ist eine einzige Katastroph... -0.385714
#
#       subjectivity  year  month  day  gesamt  qualität  behandlung  \
# 0         0.000000  2021      6    7   100.0     100.0       100.0
# 1         0.000000  2021      5   25   100.0     100.0       100.0
# 2         0.000000  2021      5   11   100.0     100.0       100.0
# 3         0.000000  2021      5    9   100.0     100.0       100.0
# 4         0.000000  2021      5    7   100.0     100.0       100.0
# ...            ...   ...    ...  ...     ...       ...         ...
# 2053      0.000000  2013      7   23    33.0      33.0        67.0
# 2054      0.050000  2013      3   19     0.0       0.0         0.0
# 2055      0.066667  2009     12    5   100.0     100.0        67.0
# 2056      0.083333  2009     10   25     0.0       0.0         0.0
# 2057      0.000000  2009      1   26     0.0       0.0         0.0
#
#       verwaltung  ausstattung  positive  group
# 0          100.0        100.0         1      1
# 1          100.0         67.0         1      1
# 2          100.0        100.0         1      1
# 3           67.0        100.0         1      1
# 4          100.0         67.0         1      1
# ...          ...          ...       ...    ...
# 2053         0.0         33.0         1      3
# 2054         0.0          0.0         1      3
# 2055       100.0        100.0         1      3
# 2056         0.0          0.0         0      3
# 2057         0.0          0.0         0      3
#
# [2058 rows x 18 columns]

# %% [markdown]
# ### Google Dataset

# %%
klinik_bewertungen_google_afterModeling=klinik_bewertungen_google_afterModeling.rename({'Name der Klinik':'name','Textuelle Bewertung':'komment','Sternebewertung':'sterne', 'Polaritiy':'polarity','Subjectivity':'subjectivity','Likes':'likes','Gruppe':'group'}, axis='columns')
klinik_bewertungen_google_afterModeling
# Out:
#       index                            name  \
# 0         0     Herzogin Elisabeth Hospital
# 1         1     Herzogin Elisabeth Hospital
# 2         2     Herzogin Elisabeth Hospital
# 3         3     Herzogin Elisabeth Hospital
# 4         4     Herzogin Elisabeth Hospital
# ...     ...                             ...
# 1482   1482  Psychiatrische Klinik Lüneburg
# 1483   1483  Psychiatrische Klinik Lüneburg
# 1484   1484  Psychiatrische Klinik Lüneburg
# 1485   1485  Psychiatrische Klinik Lüneburg
# 1486   1486  Psychiatrische Klinik Lüneburg
#
#                                                 komment  sterne  polarity  \
# 0     Vor der Corona Pandemie hätte ich jeden zugest...       2  0.283333
# 1     Tolles Krankenhaus,  trotzdem bin ich lieber g...       4  0.500000
# 2     Lungenembolie!**Ein Tag ITS, phantastische Für...       5  0.333333
# 3                      Alles sehr gut. Volle Punktzahl!       5  0.500000
# 4     Ich werde nie wieder in ein anderes Krankenhau...       5  0.212500
# ...                                                 ...     ...       ...
# 1482  Ratiopharms Rache... leicht anmaßende Azubis u...       1  1.000000
# 1483                                     Es war schlimm       1 -1.000000
# 1484                                   Menschenunwürdig       1 -1.000000
# 1485                             Nicht gute Mitarbeiter       3 -0.500000
# 1486  (Übersetzt von Google) Oben!!****(Original)**T...       5  0.500000
#
#       subjectivity  year  likes  positive  group
# 0              0.0  2021      1         0      1
# 1              0.0  2020      1         1      1
# 2              0.0  2021      1         1      1
# 3              0.0  2018      4         1      1
# 4              0.0  2021      1         0      1
# ...            ...   ...    ...       ...    ...
# 1482           0.0  2017      1         1      3
# 1483           0.0  2019      0         0      3
# 1484           0.0  2019      0         0      3
# 1485           0.0  2016      0         0      3
# 1486           0.0  2017      0         1      3
#
# [1487 rows x 10 columns]

# %% [markdown]
# ## Merge Datasets

# %% [markdown]
# ### Spaltennamen standardisieren

# %% [markdown]
# ### KlinikbewertungenDe Dataset

# %%
klinik_bewertungen_afterModeling["sterne"]=[None for i in range(2058)]

# %%
klinik_bewertungen_afterModeling["likes"]=[None for i in range(2058)]

# %%
klinik_bewertungen_afterModeling["source"]=['klinikDe' for i in range(2058)]

# %%
klinik_bewertungen_afterModeling.head(1)
# Out:
#    index                         name        titel       datum fachbereich  \
# 0      0  Herzogin Elisabeth Hospital  Superklinik  2021-06-07  Orthopädie
#
#                                              komment  polarity  subjectivity  \
# 0  Bestens durchorganisiert.gutes Personal geht i...       0.0           0.0
#
#    year  month  ...  gesamt  qualität  behandlung  verwaltung  ausstattung  \
# 0  2021      6  ...   100.0     100.0       100.0       100.0        100.0
#
#    positive  group  sterne likes    source
# 0         1      1    None  None  klinikDe
#
# [1 rows x 21 columns]

# %% [markdown]
# ### Google Dataset

# %%
klinik_bewertungen_google_afterModeling["titel"]=[None for i in range(1487)]
klinik_bewertungen_google_afterModeling['datum']=[None for i in range(1487)]
klinik_bewertungen_google_afterModeling['fachbereich']=[None for i in range(1487)]
klinik_bewertungen_google_afterModeling['month']=[None for i in range(1487)]
klinik_bewertungen_google_afterModeling['day']=[None for i in range(1487)]
klinik_bewertungen_google_afterModeling['gesamt']=[None for i in range(1487)]
klinik_bewertungen_google_afterModeling['qualität']=[None for i in range(1487)]
klinik_bewertungen_google_afterModeling['behandlung']=[None for i in range(1487)]
klinik_bewertungen_google_afterModeling['verwaltung']=[None for i in range(1487)]
klinik_bewertungen_google_afterModeling['ausstattung']=[None for i in range(1487)]
klinik_bewertungen_google_afterModeling["source"]=['googleMaps' for i in range(1487)]

# %%
klinik_bewertungen_google_afterModeling.head(1)
# Out:
#    index                         name  \
# 0      0  Herzogin Elisabeth Hospital
#
#                                              komment  sterne  polarity  \
# 0  Vor der Corona Pandemie hätte ich jeden zugest...       2  0.283333
#
#    subjectivity  year  likes  positive  group  ... datum fachbereich month  \
# 0           0.0  2021      1         0      1  ...  None        None  None
#
#     day gesamt qualität behandlung verwaltung ausstattung      source
# 0  None   None     None       None       None        None  googleMaps
#
# [1 rows x 21 columns]

# %%
#change index column for merge
klinik_bewertungen_google_afterModeling['index']=[i for i in range (2058,3545)]

# %%
klinik_bewertungen_google_afterModeling.columns
# Out:
# Index(['index', 'name', 'komment', 'sterne', 'polarity', 'subjectivity',
#        'year', 'likes', 'positive', 'group', 'titel', 'datum', 'fachbereich',
#        'month', 'day', 'gesamt', 'qualität', 'behandlung', 'verwaltung',
#        'ausstattung', 'source'],
#       dtype='object')

# %%
klinik_bewertungen_afterModeling.columns
# Out:
# Index(['index', 'name', 'titel', 'datum', 'fachbereich', 'komment', 'polarity',
#        'subjectivity', 'year', 'month', 'day', 'gesamt', 'qualität',
#        'behandlung', 'verwaltung', 'ausstattung', 'positive', 'group',
#        'sterne', 'likes', 'source'],
#       dtype='object')

# %%
df1=klinik_bewertungen_google_afterModeling
df1
# Out:
#       index                            name  \
# 0      2058     Herzogin Elisabeth Hospital
# 1      2059     Herzogin Elisabeth Hospital
# 2      2060     Herzogin Elisabeth Hospital
# 3      2061     Herzogin Elisabeth Hospital
# 4      2062     Herzogin Elisabeth Hospital
# ...     ...                             ...
# 1482   3540  Psychiatrische Klinik Lüneburg
# 1483   3541  Psychiatrische Klinik Lüneburg
# 1484   3542  Psychiatrische Klinik Lüneburg
# 1485   3543  Psychiatrische Klinik Lüneburg
# 1486   3544  Psychiatrische Klinik Lüneburg
#
#                                                 komment  sterne  polarity  \
# 0     Vor der Corona Pandemie hätte ich jeden zugest...       2  0.283333
# 1     Tolles Krankenhaus,  trotzdem bin ich lieber g...       4  0.500000
# 2     Lungenembolie!**Ein Tag ITS, phantastische Für...       5  0.333333
# 3                      Alles sehr gut. Volle Punktzahl!       5  0.500000
# 4     Ich werde nie wieder in ein anderes Krankenhau...       5  0.212500
# ...                                                 ...     ...       ...
# 1482  Ratiopharms Rache... leicht anmaßende Azubis u...       1  1.000000
# 1483                                     Es war schlimm       1 -1.000000
# 1484                                   Menschenunwürdig       1 -1.000000
# 1485                             Nicht gute Mitarbeiter       3 -0.500000
# 1486  (Übersetzt von Google) Oben!!****(Original)**T...       5  0.500000
#
#       subjectivity  year  likes  positive  group  ... datum fachbereich month  \
# 0              0.0  2021      1         0      1  ...  None        None  None
# 1              0.0  2020      1         1      1  ...  None        None  None
# 2              0.0  2021      1         1      1  ...  None        None  None
# 3              0.0  2018      4         1      1  ...  None        None  None
# 4              0.0  2021      1         0      1  ...  None        None  None
# ...            ...   ...    ...       ...    ...  ...   ...         ...   ...
# 1482           0.0  2017      1         1      3  ...  None        None  None
# 1483           0.0  2019      0         0      3  ...  None        None  None
# 1484           0.0  2019      0         0      3  ...  None        None  None
# 1485           0.0  2016      0         0      3  ...  None        None  None
# 1486           0.0  2017      0         1      3  ...  None        None  None
#
#        day gesamt qualität behandlung verwaltung ausstattung      source
# 0     None   None     None       None       None        None  googleMaps
# 1     None   None     None       None       None        None  googleMaps
# 2     None   None     None       None       None        None  googleMaps
# 3     None   None     None       None       None        None  googleMaps
# 4     None   None     None       None       None        None  googleMaps
# ...    ...    ...      ...        ...        ...         ...         ...
# 1482  None   None     None       None       None        None  googleMaps
# 1483  None   None     None       None       None        None  googleMaps
# 1484  None   None     None       None       None        None  googleMaps
# 1485  None   None     None       None       None        None  googleMaps
# 1486  None   None     None       None       None        None  googleMaps
#
# [1487 rows x 21 columns]

# %%
df2=klinik_bewertungen_afterModeling
df2
# Out:
#       index                            name                            titel  \
# 0         0     Herzogin Elisabeth Hospital                      Superklinik
# 1         1     Herzogin Elisabeth Hospital       Kranken- oder Hotelzimmer?
# 2         2     Herzogin Elisabeth Hospital                          Knie OP
# 3         3     Herzogin Elisabeth Hospital         Beste Erfahrungen im HEH
# 4         4     Herzogin Elisabeth Hospital    Superkompetent und freundlich
# ...     ...                             ...                              ...
# 2053   2053  Psychiatrische Klinik Lüneburg             Hilft nur in Krisen!
# 2054   2054  Psychiatrische Klinik Lüneburg  Mir gings schlechter als vorher
# 2055   2055  Psychiatrische Klinik Lüneburg      Eine positive Überraschung!
# 2056   2056  Psychiatrische Klinik Lüneburg      Tagesklinik Uelzener Straße
# 2057   2057  Psychiatrische Klinik Lüneburg         Eine einzige Katastrophe
#
#            datum         fachbereich  \
# 0     2021-06-07          Orthopädie
# 1     2021-05-25     Unfallchirurgie
# 2     2021-05-11          Orthopädie
# 3     2021-05-09           Chirurgie
# 4     2021-05-07      Gefäßchirurgie
# ...          ...                 ...
# 2053  2013-07-23  Kind/Jugend-Psych.
# 2054  2013-03-19         Psychiatrie
# 2055  2009-12-05         Psychiatrie
# 2056  2009-10-25         Psychiatrie
# 2057  2009-01-26  Kind/Jugend-Psych.
#
#                                                 komment  polarity  \
# 0     Bestens durchorganisiert.gutes Personal geht i...  0.000000
# 1     Bin nach einem Autounfall im HEH gewesen und h...  0.340000
# 2     Wurde bereits im Sept. 2020 am Knie operiert. ...  0.242857
# 3     Da ich zeit meines Lebens noch nie einen Krank...  0.536111
# 4     Das gesamte Personal von der Notaufnahme über ...  0.428571
# ...                                                 ...       ...
# 2053  Ich war in 2 verschiedenen Häusern. (ehm.) Hau...  0.333333
# 2054  Ich war vor kuzen Patientrin auf der Station 1...  0.115833
# 2055  Ich befinde mich seit einigen Wochen in Behand...  0.611333
# 2056  Ich kann mich Angie nur anschließen! Diese Tag... -0.175000
# 2057  Hallo,diese Klinik ist eine einzige Katastroph... -0.385714
#
#       subjectivity  year  month  ...  gesamt  qualität  behandlung  \
# 0         0.000000  2021      6  ...   100.0     100.0       100.0
# 1         0.000000  2021      5  ...   100.0     100.0       100.0
# 2         0.000000  2021      5  ...   100.0     100.0       100.0
# 3         0.000000  2021      5  ...   100.0     100.0       100.0
# 4         0.000000  2021      5  ...   100.0     100.0       100.0
# ...            ...   ...    ...  ...     ...       ...         ...
# 2053      0.000000  2013      7  ...    33.0      33.0        67.0
# 2054      0.050000  2013      3  ...     0.0       0.0         0.0
# 2055      0.066667  2009     12  ...   100.0     100.0        67.0
# 2056      0.083333  2009     10  ...     0.0       0.0         0.0
# 2057      0.000000  2009      1  ...     0.0       0.0         0.0
#
#       verwaltung  ausstattung  positive  group  sterne likes    source
# 0          100.0        100.0         1      1    None  None  klinikDe
# 1          100.0         67.0         1      1    None  None  klinikDe
# 2          100.0        100.0         1      1    None  None  klinikDe
# 3           67.0        100.0         1      1    None  None  klinikDe
# 4          100.0         67.0         1      1    None  None  klinikDe
# ...          ...          ...       ...    ...     ...   ...       ...
# 2053         0.0         33.0         1      3    None  None  klinikDe
# 2054         0.0          0.0         1      3    None  None  klinikDe
# 2055       100.0        100.0         1      3    None  None  klinikDe
# 2056         0.0          0.0         0      3    None  None  klinikDe
# 2057         0.0          0.0         0      3    None  None  klinikDe
#
# [2058 rows x 21 columns]

# %%
concated_df=pd.concat([df2, df1])

# %%
concated_df
# Out:
#       index                            name                          titel  \
# 0         0     Herzogin Elisabeth Hospital                    Superklinik
# 1         1     Herzogin Elisabeth Hospital     Kranken- oder Hotelzimmer?
# 2         2     Herzogin Elisabeth Hospital                        Knie OP
# 3         3     Herzogin Elisabeth Hospital       Beste Erfahrungen im HEH
# 4         4     Herzogin Elisabeth Hospital  Superkompetent und freundlich
# ...     ...                             ...                            ...
# 1482   3540  Psychiatrische Klinik Lüneburg                           None
# 1483   3541  Psychiatrische Klinik Lüneburg                           None
# 1484   3542  Psychiatrische Klinik Lüneburg                           None
# 1485   3543  Psychiatrische Klinik Lüneburg                           None
# 1486   3544  Psychiatrische Klinik Lüneburg                           None
#
#            datum      fachbereich  \
# 0     2021-06-07       Orthopädie
# 1     2021-05-25  Unfallchirurgie
# 2     2021-05-11       Orthopädie
# 3     2021-05-09        Chirurgie
# 4     2021-05-07   Gefäßchirurgie
# ...          ...              ...
# 1482        None             None
# 1483        None             None
# 1484        None             None
# 1485        None             None
# 1486        None             None
#
#                                                 komment  polarity  \
# 0     Bestens durchorganisiert.gutes Personal geht i...  0.000000
# 1     Bin nach einem Autounfall im HEH gewesen und h...  0.340000
# 2     Wurde bereits im Sept. 2020 am Knie operiert. ...  0.242857
# 3     Da ich zeit meines Lebens noch nie einen Krank...  0.536111
# 4     Das gesamte Personal von der Notaufnahme über ...  0.428571
# ...                                                 ...       ...
# 1482  Ratiopharms Rache... leicht anmaßende Azubis u...  1.000000
# 1483                                     Es war schlimm -1.000000
# 1484                                   Menschenunwürdig -1.000000
# 1485                             Nicht gute Mitarbeiter -0.500000
# 1486  (Übersetzt von Google) Oben!!****(Original)**T...  0.500000
#
#       subjectivity  year month  ... gesamt qualität behandlung verwaltung  \
# 0              0.0  2021     6  ...    100      100        100        100
# 1              0.0  2021     5  ...    100      100        100        100
# 2              0.0  2021     5  ...    100      100        100        100
# 3              0.0  2021     5  ...    100      100        100         67
# 4              0.0  2021     5  ...    100      100        100        100
# ...            ...   ...   ...  ...    ...      ...        ...        ...
# 1482           0.0  2017  None  ...   None     None       None       None
# 1483           0.0  2019  None  ...   None     None       None       None
# 1484           0.0  2019  None  ...   None     None       None       None
# 1485           0.0  2016  None  ...   None     None       None       None
# 1486           0.0  2017  None  ...   None     None       None       None
#
#      ausstattung positive  group  sterne likes      source
# 0            100        1      1    None  None    klinikDe
# 1             67        1      1    None  None    klinikDe
# 2            100        1      1    None  None    klinikDe
# 3            100        1      1    None  None    klinikDe
# 4             67        1      1    None  None    klinikDe
# ...          ...      ...    ...     ...   ...         ...
# 1482        None        1      3       1     1  googleMaps
# 1483        None        0      3       1     0  googleMaps
# 1484        None        0      3       1     0  googleMaps
# 1485        None        0      3       3     0  googleMaps
# 1486        None        1      3       5     0  googleMaps
#
# [3545 rows x 21 columns]

# %%
concated_df.index=concated_df['index']

# %%
concated_df
# Out:
#        index                            name                          titel  \
# index
# 0          0     Herzogin Elisabeth Hospital                    Superklinik
# 1          1     Herzogin Elisabeth Hospital     Kranken- oder Hotelzimmer?
# 2          2     Herzogin Elisabeth Hospital                        Knie OP
# 3          3     Herzogin Elisabeth Hospital       Beste Erfahrungen im HEH
# 4          4     Herzogin Elisabeth Hospital  Superkompetent und freundlich
# ...      ...                             ...                            ...
# 3540    3540  Psychiatrische Klinik Lüneburg                           None
# 3541    3541  Psychiatrische Klinik Lüneburg                           None
# 3542    3542  Psychiatrische Klinik Lüneburg                           None
# 3543    3543  Psychiatrische Klinik Lüneburg                           None
# 3544    3544  Psychiatrische Klinik Lüneburg                           None
#
#             datum      fachbereich  \
# index
# 0      2021-06-07       Orthopädie
# 1      2021-05-25  Unfallchirurgie
# 2      2021-05-11       Orthopädie
# 3      2021-05-09        Chirurgie
# 4      2021-05-07   Gefäßchirurgie
# ...           ...              ...
# 3540         None             None
# 3541         None             None
# 3542         None             None
# 3543         None             None
# 3544         None             None
#
#                                                  komment  polarity  \
# index
# 0      Bestens durchorganisiert.gutes Personal geht i...  0.000000
# 1      Bin nach einem Autounfall im HEH gewesen und h...  0.340000
# 2      Wurde bereits im Sept. 2020 am Knie operiert. ...  0.242857
# 3      Da ich zeit meines Lebens noch nie einen Krank...  0.536111
# 4      Das gesamte Personal von der Notaufnahme über ...  0.428571
# ...                                                  ...       ...
# 3540   Ratiopharms Rache... leicht anmaßende Azubis u...  1.000000
# 3541                                      Es war schlimm -1.000000
# 3542                                    Menschenunwürdig -1.000000
# 3543                              Nicht gute Mitarbeiter -0.500000
# 3544   (Übersetzt von Google) Oben!!****(Original)**T...  0.500000
#
#        subjectivity  year month  ... gesamt qualität behandlung verwaltung  \
# index                            ...
# 0               0.0  2021     6  ...    100      100        100        100
# 1               0.0  2021     5  ...    100      100        100        100
# 2               0.0  2021     5  ...    100      100        100        100
# 3               0.0  2021     5  ...    100      100        100         67
# 4               0.0  2021     5  ...    100      100        100        100
# ...             ...   ...   ...  ...    ...      ...        ...        ...
# 3540            0.0  2017  None  ...   None     None       None       None
# 3541            0.0  2019  None  ...   None     None       None       None
# 3542            0.0  2019  None  ...   None     None       None       None
# 3543            0.0  2016  None  ...   None     None       None       None
# 3544            0.0  2017  None  ...   None     None       None       None
#
#       ausstattung positive  group  sterne likes      source
# index
# 0             100        1      1    None  None    klinikDe
# 1              67        1      1    None  None    klinikDe
# 2             100        1      1    None  None    klinikDe
# 3             100        1      1    None  None    klinikDe
# 4              67        1      1    None  None    klinikDe
# ...           ...      ...    ...     ...   ...         ...
# 3540         None        1      3       1     1  googleMaps
# 3541         None        0      3       1     0  googleMaps
# 3542         None        0      3       1     0  googleMaps
# 3543         None        0      3       3     0  googleMaps
# 3544         None        1      3       5     0  googleMaps
#
# [3545 rows x 21 columns]

# %%
concated_df.shape
# Out:
# (3545, 21)

# %%
concated_df['name'][:2058].unique()
# Out:
# array(['Herzogin Elisabeth Hospital', 'Klinik am Zuckerberg',
#        'Klinikum Wolfsburg', 'Klinikum Peine', 'St. Martini Krankenhaus',
#        'DIAKOVERE Henriettenstift', 'Eilenriede Klinik Hannover',
#        'Sophienklinik', 'KRH Klinikum Agness Karll Laatzen',
#        'Klinikum Wahrendorff', 'AMEOS Klinikum Hildesheim',
#        'Helios Kliniken Mittelweser', 'HELIOS Klinik Cuxhaven',
#        'AMEOS Klinikum Seepark Geestland', 'Krankenhaus Buchholz',
#        'Krankenhaus Winsen', 'Psychiatrische Klinik Lüneburg'],
#       dtype=object)

# %%
concated_df['name'][2058:3345].unique()
# Out:
# array(['Herzogin Elisabeth Hospital', 'Klinik Am Zuckerberg GmbH',
#        'Klinikum Wolfsburg in Wolfsburg', 'Klinikum Peine gGmbH',
#        'St. Martini Krankenhaus', 'DIAKOVERE Henriettenstift',
#        'Eilenriede Klinik Hannover', 'Sophienklinik GmbH',
#        'KRH Klinikum Agnes Karll Laatzen', 'Klinikum Wahrendorff',
#        'AMEOS Klinikum Hildesheim', 'Helios Kliniken Mittelweser',
#        'HELIOS Klinik Cuxhaven', 'AMEOS Klinikum Seepark Geestland',
#        'Krankenhaus Buchholz'], dtype=object)

# %%
klinik_names=concated_df['name'].to_list()
len(klinik_names)
# Out:
# 3545

# %%
len(set(klinik_names))
# Out:
# 22

# %%
for i in range (3545):
    if klinik_names[i]=='Sophienklinik GmbH':
        klinik_names[i]='Sophienklinik'
    if klinik_names[i]=='Klinik Am Zuckerberg GmbH':
        klinik_names[i]='Klinik am Zuckerberg'
    if klinik_names[i]=='Klinikum Wolfsburg in Wolfsburg':
        klinik_names[i]='Klinikum Wolfsburg'
        
    if klinik_names[i]=='Klinikum Peine gGmbH':
        klinik_names[i]='Klinikum Peine'
    if klinik_names[i]=='Klinik Am Zuckerberg GmbH':
        klinik_names[i]='Klinik am Zuckerberg'
    if klinik_names[i]=='KRH Klinikum Agnes Karll Laatzen':
        klinik_names[i]='KRH Klinikum Agness Karll Laatzen'

# %%
set(klinik_names)
# Out:
# {'AMEOS Klinikum Hildesheim',
#  'AMEOS Klinikum Seepark Geestland',
#  'DIAKOVERE Henriettenstift',
#  'Eilenriede Klinik Hannover',
#  'HELIOS Klinik Cuxhaven',
#  'Helios Kliniken Mittelweser',
#  'Herzogin Elisabeth Hospital',
#  'KRH Klinikum Agness Karll Laatzen',
#  'Klinik am Zuckerberg',
#  'Klinikum Peine',
#  'Klinikum Wahrendorff',
#  'Klinikum Wolfsburg',
#  'Krankenhaus Buchholz',
#  'Krankenhaus Winsen',
#  'Psychiatrische Klinik Lüneburg',
#  'Sophienklinik',
#  'St. Martini Krankenhaus'}

# %%
concated_df['name']=klinik_names

# %%
len(concated_df['name'].unique())
# Out:
# 17

# %%
concated_df[2400:2450]
# Out:
#        index            name titel datum fachbereich  \
# index
# 2400    2400  Klinikum Peine  None  None        None
# 2401    2401  Klinikum Peine  None  None        None
# 2402    2402  Klinikum Peine  None  None        None
# 2403    2403  Klinikum Peine  None  None        None
# 2404    2404  Klinikum Peine  None  None        None
# 2405    2405  Klinikum Peine  None  None        None
# 2406    2406  Klinikum Peine  None  None        None
# 2407    2407  Klinikum Peine  None  None        None
# 2408    2408  Klinikum Peine  None  None        None
# 2409    2409  Klinikum Peine  None  None        None
# 2410    2410  Klinikum Peine  None  None        None
# 2411    2411  Klinikum Peine  None  None        None
# 2412    2412  Klinikum Peine  None  None        None
# 2413    2413  Klinikum Peine  None  None        None
# 2414    2414  Klinikum Peine  None  None        None
# 2415    2415  Klinikum Peine  None  None        None
# 2416    2416  Klinikum Peine  None  None        None
# 2417    2417  Klinikum Peine  None  None        None
# 2418    2418  Klinikum Peine  None  None        None
# 2419    2419  Klinikum Peine  None  None        None
# 2420    2420  Klinikum Peine  None  None        None
# 2421    2421  Klinikum Peine  None  None        None
# 2422    2422  Klinikum Peine  None  None        None
# 2423    2423  Klinikum Peine  None  None        None
# 2424    2424  Klinikum Peine  None  None        None
# 2425    2425  Klinikum Peine  None  None        None
# 2426    2426  Klinikum Peine  None  None        None
# 2427    2427  Klinikum Peine  None  None        None
# 2428    2428  Klinikum Peine  None  None        None
# 2429    2429  Klinikum Peine  None  None        None
# 2430    2430  Klinikum Peine  None  None        None
# 2431    2431  Klinikum Peine  None  None        None
# 2432    2432  Klinikum Peine  None  None        None
# 2433    2433  Klinikum Peine  None  None        None
# 2434    2434  Klinikum Peine  None  None        None
# 2435    2435  Klinikum Peine  None  None        None
# 2436    2436  Klinikum Peine  None  None        None
# 2437    2437  Klinikum Peine  None  None        None
# 2438    2438  Klinikum Peine  None  None        None
# 2439    2439  Klinikum Peine  None  None        None
# 2440    2440  Klinikum Peine  None  None        None
# 2441    2441  Klinikum Peine  None  None        None
# 2442    2442  Klinikum Peine  None  None        None
# 2443    2443  Klinikum Peine  None  None        None
# 2444    2444  Klinikum Peine  None  None        None
# 2445    2445  Klinikum Peine  None  None        None
# 2446    2446  Klinikum Peine  None  None        None
# 2447    2447  Klinikum Peine  None  None        None
# 2448    2448  Klinikum Peine  None  None        None
# 2449    2449  Klinikum Peine  None  None        None
#
#                                                  komment  polarity  \
# index
# 2400   Sehr nettes, herzliches Personal (E02, Notaufn...  0.333333
# 2401   Ich habe selten, in den letzten 10 Jahren so e...  0.050000
# 2402     Ich wurde gut, wenn auch nicht Zügig behandelt.  1.000000
# 2403   Mit Verdacht auf Herzinfarkt hier sehr gut beh...  0.444444
# 2404   Hatte einen Verdacht von einer Blinddarmentzün...  0.100000
# 2405   Tolles Team, alles gut geklappt. Chirurgie und...  1.000000
# 2406   Ich war in den letzten Wochen zu Beratungsgesp...  0.308333
# 2407   Viel zu lange Wartezeiten, schlechtes Personal... -0.250000
# 2408   Ich habe am 4 September ein neues Kniegelenk (...  0.421429
# 2409   Ok, die Unfallaufnahme hat 5 von 5 Sterne verd...  0.242857
# 2410   Extrem unfreundliche und herablassende Damen i... -0.308333
# 2411   Notaufnahme:****3 Stunden Wartezeit. 👎**Netter... -0.250000
# 2412   Sehr unfreundlich, unprofessionell und unmänsc... -0.200000
# 2413   Ich wurde vor zwei Wochen im Klinikum Peine in...  0.500000
# 2414   Ich wurde mit sehr hohem Blutdruck und Atembes...  0.039286
# 2415   Wenn ich 0 Sterne geben könnte würde ich das t... -0.250000
# 2416   6000€ einfach so geklaut.**03.08.2014****Nachd...  0.350000
# 2417   Ich war gestern mit größeren Darmproblemen im ...  0.616667
# 2418   Ein Krankenhaus ist kein Luxushotel. Wichtig i...  0.170000
# 2419   Ich wurde mit Herzprobleme eingeliefert und mu...  0.321429
# 2420   wir haben unser Kind in Klinikum Peine bekomme...  0.333333
# 2421      Eine deutliche Verbesserung in jeder Hinsicht!  0.000000
# 2422   Unfreundlicher Personal und nicht zu empfehlen da  0.000000
# 2423   Ein Lob an das Team aus der Notaufnahme trotz ...  0.300000
# 2424   Hallo**Musst leider meine Galle entferne lasse...  1.000000
# 2425   Ich war sehr zufrieden. Ich habe meine drei Ki... -0.021429
# 2426   Warum hat man mich bei einer entzündete OP Wun...  0.000000
# 2427   Wir würden schnell, freundlich und gut in der ...  1.000000
# 2428   Eine geplante Koloskopie wurde bei mir im Kran...  0.222222
# 2429   Die an der Rezeption bei dem Bereitschaftsdien... -0.433333
# 2430   Netter Empfang an der Info, aber rundum ein un... -0.411111
# 2431   Total unfreundlich in der Notaufnahme!****Ich ... -0.500000
# 2432                           Wirkt alles sehr gehetzt.  0.000000
# 2433   Ich wurde am Sonntag, den 10.02.19, nach einem...  0.123333
# 2434   Es ist nicht zu glauben das man da 2 Stunden a...  0.069231
# 2435   Wie ich erfahren durfte weiss hier oftmals nic...  0.000000
# 2436   Die Notaufnahme ist grauenvoll. Motorradunfall... -0.250000
# 2437   Notaufnahme Personal unhöflich,unfreundlich**D... -0.250000
# 2438   Meine Verlobte bekam im Laufe des Tages zunehm... -0.154545
# 2439   Habe Schlaganfall gehabt 2016 haben sich rühre...  0.700000
# 2440   Mein Mann hatte Um 10 Uhr Termin zur op**Er si...  0.000000
# 2441   Als Mitarbeiter könnte ich viel erzählen, dahe...  0.000000
# 2442   Bei mir wurde ein Innenmenikus operiert und de...  0.285714
# 2443   1 Stern ist schon sogar zu viel, mann kommt da...  0.550000
# 2444                                             Ganz ok  0.000000
# 2445   Bedauerlicherweise können hier nicht null Ster...  0.280769
# 2446   Schnelle und kompetente Hilfe, auch wenn es nu...  1.000000
# 2447   Mit „Angst“ und extremen Vorbehalten wegen Ver...  0.629167
# 2448   Notaufnahme 5 Stunden Wartezeit...**Glassplitt...  0.140000
# 2449   Nach einer aufwendigen Operation durch Herrn P...  0.277778
#
#        subjectivity  year month  ... gesamt qualität behandlung verwaltung  \
# index                            ...
# 2400       0.000000  2020  None  ...   None     None       None       None
# 2401       0.166667  2020  None  ...   None     None       None       None
# 2402       0.000000  2020  None  ...   None     None       None       None
# 2403       0.000000  2020  None  ...   None     None       None       None
# 2404       0.100000  2019  None  ...   None     None       None       None
# 2405       0.000000  2020  None  ...   None     None       None       None
# 2406       0.000000  2020  None  ...   None     None       None       None
# 2407       0.250000  2020  None  ...   None     None       None       None
# 2408       0.000000  2020  None  ...   None     None       None       None
# 2409       0.000000  2020  None  ...   None     None       None       None
# 2410       0.300000  2020  None  ...   None     None       None       None
# 2411       0.000000  2019  None  ...   None     None       None       None
# 2412       0.000000  2020  None  ...   None     None       None       None
# 2413       0.000000  2020  None  ...   None     None       None       None
# 2414       0.071429  2018  None  ...   None     None       None       None
# 2415       0.250000  2019  None  ...   None     None       None       None
# 2416       0.000000  2020  None  ...   None     None       None       None
# 2417       0.000000  2019  None  ...   None     None       None       None
# 2418       0.000000  2018  None  ...   None     None       None       None
# 2419       0.142857  2020  None  ...   None     None       None       None
# 2420       0.666667  2019  None  ...   None     None       None       None
# 2421       0.000000  2020  None  ...   None     None       None       None
# 2422       0.000000  2020  None  ...   None     None       None       None
# 2423       0.125000  2019  None  ...   None     None       None       None
# 2424       0.000000  2018  None  ...   None     None       None       None
# 2425       0.000000  2018  None  ...   None     None       None       None
# 2426       0.000000  2019  None  ...   None     None       None       None
# 2427       0.000000  2019  None  ...   None     None       None       None
# 2428       0.444444  2019  None  ...   None     None       None       None
# 2429       0.000000  2020  None  ...   None     None       None       None
# 2430       0.000000  2019  None  ...   None     None       None       None
# 2431       0.000000  2020  None  ...   None     None       None       None
# 2432       0.000000  2020  None  ...   None     None       None       None
# 2433       0.000000  2019  None  ...   None     None       None       None
# 2434       0.000000  2019  None  ...   None     None       None       None
# 2435       0.000000  2019  None  ...   None     None       None       None
# 2436       0.000000  2018  None  ...   None     None       None       None
# 2437       0.200000  2020  None  ...   None     None       None       None
# 2438       0.090909  2019  None  ...   None     None       None       None
# 2439       0.000000  2018  None  ...   None     None       None       None
# 2440       0.800000  2019  None  ...   None     None       None       None
# 2441       1.000000  2018  None  ...   None     None       None       None
# 2442       0.000000  2017  None  ...   None     None       None       None
# 2443       0.125000  2019  None  ...   None     None       None       None
# 2444       0.000000  2019  None  ...   None     None       None       None
# 2445       0.153846  2019  None  ...   None     None       None       None
# 2446       0.000000  2018  None  ...   None     None       None       None
# 2447       0.333333  2019  None  ...   None     None       None       None
# 2448       0.000000  2019  None  ...   None     None       None       None
# 2449       0.166667  2018  None  ...   None     None       None       None
#
#       ausstattung positive  group  sterne likes      source
# index
# 2400         None        1      1       5     7  googleMaps
# 2401         None        0      1       1     2  googleMaps
# 2402         None        1      1       4     2  googleMaps
# 2403         None        1      1       5     8  googleMaps
# 2404         None        0      1       4     1  googleMaps
# 2405         None        1      1       5     6  googleMaps
# 2406         None        1      1       5     1  googleMaps
# 2407         None        0      1       2     9  googleMaps
# 2408         None        1      1       5     1  googleMaps
# 2409         None        0      1       1     1  googleMaps
# 2410         None        0      1       1     6  googleMaps
# 2411         None        0      1       1     1  googleMaps
# 2412         None        0      1       1     4  googleMaps
# 2413         None        1      1       5     1  googleMaps
# 2414         None        0      1       5     3  googleMaps
# 2415         None        0      1       1     2  googleMaps
# 2416         None        1      1       1     1  googleMaps
# 2417         None        1      1       5     3  googleMaps
# 2418         None        0      1       4     4  googleMaps
# 2419         None        1      1       1     3  googleMaps
# 2420         None        1      1       5     1  googleMaps
# 2421         None        0      1       5     1  googleMaps
# 2422         None        0      1       1     5  googleMaps
# 2423         None        1      1       5     2  googleMaps
# 2424         None        1      1       4     7  googleMaps
# 2425         None        0      1       4     2  googleMaps
# 2426         None        0      1       1     5  googleMaps
# 2427         None        1      1       5     1  googleMaps
# 2428         None        0      1       5     6  googleMaps
# 2429         None        0      1       1     2  googleMaps
# 2430         None        0      1       1     6  googleMaps
# 2431         None        0      1       1     1  googleMaps
# 2432         None        0      1       2     1  googleMaps
# 2433         None        0      1       5     1  googleMaps
# 2434         None        0      1       1     1  googleMaps
# 2435         None        0      1       1     1  googleMaps
# 2436         None        0      1       1     4  googleMaps
# 2437         None        0      1       1     1  googleMaps
# 2438         None        0      1       1     4  googleMaps
# 2439         None        1      1       4     1  googleMaps
# 2440         None        0      1       1     2  googleMaps
# 2441         None        0      1       4     1  googleMaps
# 2442         None        0      1       5     5  googleMaps
# 2443         None        1      1       1     1  googleMaps
# 2444         None        0      1       4     3  googleMaps
# 2445         None        0      1       1     3  googleMaps
# 2446         None        1      1       4     2  googleMaps
# 2447         None        1      1       5     1  googleMaps
# 2448         None        0      1       1     2  googleMaps
# 2449         None        0      1       5     2  googleMaps
#
# [50 rows x 21 columns]

# %%
concated_df.to_csv('Dataset.csv', index=False)

# %% [markdown]
# <div style="background-color:blue; color:white; text-align:center; padding:10px"><h2>End...</h2></div>
